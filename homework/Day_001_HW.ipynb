# %%
1. 
a.這組資料為何重要
單純是因此組資料是在kaggle上歸類在初學者類別之資料，方便上手加上對於此事件有些興趣，因此選擇此資料集

b.資料從何而來 
https://www.kaggle.com/c/titanic/data

c.此資料型態為?
結構化資料。訓練資料包含欄位為：
PassengerId、Survived、Pclass、Name、Sex、Age、SibSp、Parch、Ticket、Fare、Cabin、Embarked

d.此資料可運用致哪個問題解決上 & 其評估
鐵達尼沈船事件雖至今久遠，但可從其倖存者資料統計中了解在類似災難發生時有哪些人員身分差異造成存活率之差別，進而可以提供給旅遊保險費用之相關計算(例如依性別、交通工具座艙差別計算個別保費差異)

2.想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

a. 核心問題為何 
假設目前車隊平均每日有2.5個小時是空車繞行時間，比起單靠經驗更希望能夠透過數據分析預測載客熱點分布與時段，除了能減少油耗，也能讓司機即時掌握潛在客流增加每日載客次數。
或許可先從活動人流的角度著手，依據當日活動舉辦地點時間推薦司機下一堂載客點
b. 資料從何而來 
各售票平台、車輛跳表機

c. 蒐集而來的資料型態為何
結構化資料

d. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
計算車隊平均每日空車時間是否下降、收益增加百分比

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, yp):
    mse = sum(pow(y - yp, 2)) / len(y)
    return mse

def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae


MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 200.413
# The Mean absolute error is 11.094
